# %% [markdown]
# ## Editing count

# %%
.libPaths("/picb/rnomics4/rotation/fuzhican/software/conda2_4_7/envs/r_362/lib/R/library")

library(tidyverse)
project_path="/data/rnomics6/fuzhican/project/tABE"
Time_m_path="/data/rnomics6/fuzhican/project/RNA_editing_Time_flow_fine_tune"
ABE_m_path="/picb/rnomics4/rotation/fuzhican/project/ABE_transcriptomics_off_target"
PEOT_m_path="/data/rnomics6/fuzhican/project/PE_off_target"


theme_me=theme(panel.grid.major =element_blank(), panel.grid.minor = element_blank(), panel.background = element_blank(),plot.background=element_blank(),legend.background=element_blank(),legend.box.background=element_blank(),axis.line = element_line(colour = "black",size=0.71),axis.ticks=element_line(size=0.71),axis.ticks.length=unit(4, "pt"),axis.text.x=element_text(hjust=1,vjust=1,angle=45),plot.title=element_text(hjust=0.5),strip.background=element_blank())
# Out:
# Warning message:
# “package ‘tidyverse’ was built under R version 3.6.3”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘tibble’ was built under R version 3.6.3”
# Warning message:
# “package ‘tidyr’ was built under R version 3.6.3”
# Warning message:
# “package ‘readr’ was built under R version 3.6.3”
# Warning message:
# “package ‘purrr’ was built under R version 3.6.3”
# Warning message:
# “package ‘dplyr’ was built under R version 3.6.3”
# Warning message:
# “package ‘stringr’ was built under R version 3.6.3”
# Warning message:
# “package ‘forcats’ was built under R version 3.6.3”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# ## Editing count

# %%
big_file_20220927_RNAseq_Chenjia_20220908_TrueSampleName=paste(sep="/",project_path,"RNAseq_Chenjia_20220908/Trim_Sampling32M_update/hg38/bmc/6-0-0Summary/Human_2022_09_27_big_file_sample_source-RNAseq_Chenjia_20220908_site_range-all_Trim_Sampling32M_update.tsv.gz") 

df_20220927_RNAseq_Chenjia_20220908_TrueSampleName=read.table(big_file_20220927_RNAseq_Chenjia_20220908_TrueSampleName,stringsAsFactors=FALSE,head=T,sep="\t")

# %%
head(df_20220927_RNAseq_Chenjia_20220908_TrueSampleName)

# %%
picture_path=paste(project_path,"RNAseq_Chenjia_20220908/Trim_Sampling32M_update/hg38/bmc/6-0-0Summary/BS_AND_Genome_Location_distribute/picture",sep="/")
Genome_location_list=c("Alu","Repetitive_non-Alu","Nonrepetitive")
Genome_location_color=c("#C8AB74","#706046","#DC8688")
names(Genome_location_color)=Genome_location_list


Stage_list=c('t-WQ-A2','t-A2','ABE8e', 'ABE8e-V106W', 'ABE8e-WQ','Cas9','EGFP')
treat_factor_level_breaks=Stage_list
treat_factor_level_color=c('#00A2FF', '#7A81FF', '#FF85FF',  '#CB297B','#FF9300', '#C0C0C0', '#929292')
names(treat_factor_level_color)=treat_factor_level_breaks


Sample_name_list=c('LCFRNA20220908_293FT_EGFP_rep1', 'LCFRNA20220908_293FT_Cas9_rep1',
       'LCFRNA20220908_293FT_ABE8e_rep1',
       'LCFRNA20220908_293FT_ABE8e-V106W_rep1',
       'LCFRNA20220908_293FT_ABE8e-WQ_rep1',
       'LCFRNA20220908_293FT_t-A2_rep1',
       'LCFRNA20220908_293FT_t-WQ-A2_rep1')


big_file_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName=paste(sep="/",project_path,"RNAseq_Chenjia_20220908/Trim_Sampling32M_update/hg38/bmc/6-0-0Summary/Human_2022_09_27_big_file_sample_source-RNAseq_Chenjia_20220908_site_range-all_filtered_spurious_ER5HPB3MR2_Trim_Sampling32M_update.tsv.gz")

df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName=read.table(big_file_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName,stringsAsFactors=FALSE,head=T,sep="\t")


df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName$Stage=factor(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName$Stage,levels=Stage_list)
df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName$Sample_name=factor(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName$Sample_name,levels=Sample_name_list)
df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName$Genome_Location =factor(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName$Genome_Location,levels=Genome_location_list) 
df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_site_counts_summmary<-df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName %>% group_by(BS_annotated,Sample_name,Stage,Tissue,Genome_Location)%>%summarise(Count_of_sites_across_Genome_location=n())





### total BS
df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_site_counts_summmary<-df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName%>%group_by(BS_annotated,Sample_name,Stage,Tissue,Genome_Location)%>%summarise(Count_of_sites_across_Genome_location=n())

df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_site_counts_summmary_BSAnnotated=df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_site_counts_summmary[df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_site_counts_summmary$BS_annotated!="",]
### C>T
df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_CT_site_counts_summmary<-df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName%>%subset(BS_annotated=="c>t")%>%group_by(Sample_name,Tissue,Stage)%>%summarise(Count_of_sites_across_Sample_name=n())

df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_CT_site_counts_summmary$Stage=factor(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_CT_site_counts_summmary$Stage,levels=Stage_list)

### A>G
df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_AG_site_counts_summmary<-df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName%>%subset(BS_annotated=="a>g")%>%group_by(Sample_name,Tissue,Stage)%>%summarise(Count_of_sites_across_Sample_name=n())

df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_AG_site_counts_summmary$Stage=factor(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_AG_site_counts_summmary$Stage,levels=Stage_list)
### non-C-to-U/A-to-I
df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_nonAGCT_site_counts_summmary<-df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName%>%subset(BS_annotated!="c>t"&BS_annotated!="a>g")%>%group_by(Sample_name,Tissue,Stage)%>%summarise(Count_of_sites_across_Sample_name=n())

df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_nonAGCT_site_counts_summmary$Stage=factor(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_nonAGCT_site_counts_summmary$Stage,levels=Stage_list)

# %%
df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_site_counts_summmary_BSAnnotated

# %%
head(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_CT_site_counts_summmary)

# %% [markdown]
# ### editing count sep BS Alu

# %%
head(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_site_counts_summmary)

# %%
#### picture individul tissue 0-105,000
for (stage in unique(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_site_counts_summmary_BSAnnotated$Stage)){
    print(stage)
p<-ggplot(subset(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_site_counts_summmary_BSAnnotated,Stage==stage),aes(x=BS_annotated,y=Count_of_sites_across_Genome_location))+
stat_summary(aes(fill=Genome_Location),fun.y=mean,geom="bar",position="dodge")+
# stat_summary(aes(fill=Genome_Location),fun.data=mean_sdl,fun.args = list(mult = 1), geom="errorbar", color="black",width=0.6,position=position_dodge(width=0.9))+
#     geom_point(aes(fill=Genome_Location),position=position_jitterdodge(dodge.width=0.9),
#                size=0.5)+
    scale_fill_manual(breaks=names(Genome_location_color),values=Genome_location_color)+
#     facet_wrap(~Stage,nrow = 3, scales='free')+
    scale_y_continuous(expand=expand_scale(mult = c(0, 0)),limits=c(0,105000))+
    coord_cartesian(ylim=c(0, 105000))+
    theme_me +
    theme(axis.title=element_blank(),legend.position="None",strip.background =element_blank(),strip.text = element_text(hjust=0),panel.spacing = unit(2, "lines"))
# axis.text=element_blank(),axis.text.x=element_blank(),
#
print(p)
ggsave(paste(sep="/",picture_path,paste0("Human_Editing_site_counts_hist_Tissue_sep_Genome_location_2_site_range-filtered_spurious_HPB3ER5_formated_",stage,"222.pdf")),p,width=250/72,height=135/72,units = "in",dpi=300) 
}

# %%
paste(sep="/",picture_path,paste0("Human_Editing_site_counts_hist_Tissue_sep_Genome_location_2_site_range-filtered_spurious_HPB3ER5_formated_",stage,"222.pdf")

# %% [markdown]
# ### editing ratio distribute

# %%
### all samples

# %%
head(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag)

# %%
df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag$ER

# %%
treat_factor_level_color

# %%
#Tissue_list=c("20200520_hRNF2-PE3","20200520_hRNF2-NT","20200520_hRNF2-A3A","20200520_hRNF2-BE3","20200520_hRNF2-Cas9","20200520_hRNF2-EGFP")
#df_WGS_SNV_hg38_big_file_0808$Tissue=factor(df_WGS_SNV_hg38_big_file_0808$Tissue,levels=Tissue_list)

df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag=subset(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName,BS_annotated=="a>g")
df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag$Stage=factor(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag$Stage,levels=Stage_list,labels=(Stage_list%>% 
map(function(x) paste0(length(subset(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag,Stage==x)$Stage),"\n",x)))) #labels

# df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag$Stage=factor(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag$Stage,levels=Stage_list)
# df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag$Sample_name=factor(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag$Sample_name,levels=Sample_name_list)
p<-ggplot(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag,aes(x=Stage,y=ER))+
    geom_point(size=0.5,position=position_jitter(width = 0.3, height = 0),aes(color=Stage))+
    scale_color_manual(breaks=names(treat_factor_level_color),values=treat_factor_level_color)+
    facet_wrap(~Stage,nrow = 1,scales = "free_x")+
    scale_y_continuous(expand=expand_scale(mult = c(0, 0)),limits=c(0,1),breaks=seq(0,1,0.2),sec.axis = dup_axis())+
    coord_cartesian(ylim=c(0, 1)) +
    geom_segment(x=-Inf, y=1, xend=Inf, yend=1,size=1.5)+
    #theme_me #+
    theme(panel.grid.major =element_blank(), panel.grid.minor = element_blank(), panel.background = element_blank(),plot.background=element_blank(),legend.background=element_blank(),legend.box.background=element_blank(),axis.line = element_line(colour = "black",size=0.71),axis.ticks=element_line(size=0.71),axis.ticks.length=unit(4, "pt"),axis.ticks.x = element_blank(),axis.ticks.y.right  = element_blank(),plot.title=element_text(hjust=0.5),strip.background =element_blank(),strip.text = element_text(hjust=0),panel.spacing = unit(0, "lines"),panel.border = element_rect(linetype = "solid", fill = NA,color="#828282"),legend.position="None")
    #theme(legend.position="None",strip.background =element_blank(),strip.text = element_text(hjust=0)) #axis.text.x=element_blank(),

#
p
ggsave(paste(picture_path,"Human_Editing_ratio_point_Sample_sep_site_range-filtered_spurious_ER5HPB3MR2_point_ag222.png",sep="/"),p,width=685/72,height=215/72,units = "in",dpi=300)

# %%
df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag=subset(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName,BS_annotated=="a>g")
df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag$Stage=factor(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag$Stage,levels=Stage_list)
p<-ggplot(df_20220927_RNAseq_Chenjia_20220908_filtered_spurious_ER5HPB3MR2_TrueSampleName_ag,aes(x=Stage,y=ER))+
    geom_point(size=0.5,position=position_jitter(width = 0.3, height = 0),aes(color=Stage))+
    scale_color_manual(breaks=names(treat_factor_level_color),values=treat_factor_level_color)+
    facet_wrap(~Stage,nrow = 1,scales = "free_x")+
    scale_y_continuous(expand=expand_scale(mult = c(0, 0)),limits=c(0,1),breaks=seq(0,1,0.2),sec.axis = dup_axis())+
    coord_cartesian(ylim=c(0, 1)) +
    geom_segment(x=-Inf, y=1, xend=Inf, yend=1,size=1.5)+
    #theme_me #+
    theme(panel.grid.major =element_blank(), panel.grid.minor = element_blank(), panel.background = element_blank(),plot.background=element_blank(),legend.background=element_blank(),legend.box.background=element_blank(),axis.line = element_line(colour = "black",size=0.71),axis.ticks=element_line(size=0.71),axis.ticks.length=unit(4, "pt"),axis.ticks.x = element_blank(),axis.ticks.y.right  = element_blank(),plot.title=element_text(hjust=0.5),strip.background =element_blank(),strip.text = element_text(hjust=0),panel.spacing = unit(0, "lines"),panel.border = element_rect(linetype = "solid", fill = NA,color="#828282"),legend.position="None")
    #theme(legend.position="None",strip.background =element_blank(),strip.text = element_text(hjust=0)) #axis.text.x=element_blank(),

#
p
# Out:
# plot without title
